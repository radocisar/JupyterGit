# %% [markdown]
# ## To remote all *.txt files from C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks

# %%
import os

US_Stocks_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks"

for folder in os.listdir(US_Stocks_Folder):
    #print(folder)
    Indv_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\" + folder
    #print(Indv_Folder)
    for file in os.listdir(Indv_Folder):
        if file.endswith(".txt"):
            os.remove(str(Indv_Folder+"\\"+file))

# %% [markdown]
# ## To convert all *.txt.gz files in C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks into *.txt files

# %%
US_Stocks_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks"

for folder in os.listdir(US_Stocks_Folder):
    print(folder)
    Indv_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\" + folder
    print(Indv_Folder)
    for file in os.listdir(Indv_Folder):
        patoolib.extract_archive(str(Indv_Folder+"\\"+file),
                                  outdir=Indv_Folder)
# Out:
# ADP
# C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\ADP
# patool: Extracting C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\ADP\ADP_Bars_20180824.txt.gz ...
# patool: ... C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\ADP\ADP_Bars_20180824.txt.gz extracted to `C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\ADP'.
# patool: Extracting C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\ADP\ADP_Bars_20180827.txt.gz ...
# patool: ... C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\ADP\ADP_Bars_20180827.txt.gz extracted to `C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\ADP'.
# patool: Extracting C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\ADP\ADP_Bars_20180828.txt.gz ...
# patool: ... C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\ADP\ADP_Bars_20180828.txt.gz extracted to `C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\ADP'.
# patool: Extracting C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\ADP\ADP_Bars_20180829.txt.gz ...
# ...

# %% [markdown]
# ## To search for date mismatch inside the files

# %%
import pandas as pd
import patoolib
import os

US_Stocks_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks"

for folder in os.listdir(US_Stocks_Folder):
    print(folder)
    Indv_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\" + folder
    #print(Indv_Folder)
    for file in os.listdir(Indv_Folder):
#         patoolib.extract_archive(str(Indv_Folder+"\\"+file),
#                                   outdir=Indv_Folder)
        if file.endswith(".txt"):
            #print(file)
            fd = file[len(file)-12:-4]
            #print(fd)
            df = pd.read_csv(Indv_Folder+"\\"+file,delimiter="|",
                             header=0,index_col=0,parse_dates=True)
            #print(df.index.strftime("%Y%m%d"))
            df_index_list = df.index.strftime("%Y%m%d").values.tolist()
            #print(df_index_list[:10])
            for i in df_index_list:
                if i == fd:
                    pass
                else:
                    print("Date mismatch. File: {} | File date: {} whereas item date {}. Occured at line #: {}.".
                          format(file,fd,i,df_index_list.index(i)+2))
# Out:
# ADP
# ANET
# CENX
# ECR
# INTU
# OMC
# SEAS
# TSCO
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# ...
