# %%
import os

US_Stocks_Folder = r"X:\Raw_1_sec_Bar_Data\US_Stocks"

for folder in os.listdir(US_Stocks_Folder):
    #print(folder)
    Indv_Folder = r"X:\Raw_1_sec_Bar_Data\US_Stocks\\" + folder
    #print(Indv_Folder)
    f = os.listdir(Indv_Folder)
    
    #print(os.path.getsize(Indv_Folder))
    count = 0
    for file in os.listdir(Indv_Folder):
        fp = os.path.join(Indv_Folder,file)
        count += os.path.getsize(fp)
        #print(file, "    ", os.path.getsize(fp))
    if len(f) < 35:
        print("\x1b[31m\"{}\"\x1b[0m".format(Indv_Folder), "   ", "\x1b[31m\"Count: {}     Total size: {} MB\"\x1b[0m".format(len(f), count/(1024**2)))
    else:    
        print(Indv_Folder, "   ", "Count: {}     Total size: {} MB".format(len(f), count/(1024**2))) #print("Total size: {} MB".format(count/(1024**2)))
#     if len(f) == 12:
#         print(os.path.split(Indv_Folder)[1])
#         l.append(os.path.split(Indv_Folder)[1])
#         if file.endswith(".txt"):
#             os.remove(str(Indv_Folder+"\\"+file))
# Out:
# X:\Raw_1_sec_Bar_Data\US_Stocks\\A     Count: 35     Total size: 2.462289810180664 MB
# X:\Raw_1_sec_Bar_Data\US_Stocks\\AABA     Count: 35     Total size: 3.292422294616699 MB
# X:\Raw_1_sec_Bar_Data\US_Stocks\\AAPL     Count: 35     Total size: 5.040637016296387 MB
# X:\Raw_1_sec_Bar_Data\US_Stocks\\ABT     Count: 35     Total size: 2.7190637588500977 MB
# X:\Raw_1_sec_Bar_Data\US_Stocks\\ACM     Count: 35     Total size: 2.2021350860595703 MB
# X:\Raw_1_sec_Bar_Data\US_Stocks\\ACN     Count: 35     Total size: 2.5366973876953125 MB
# X:\Raw_1_sec_Bar_Data\US_Stocks\\ADBE     Count: 35     Total size: 2.9183244705200195 MB
# X:\Raw_1_sec_Bar_Data\US_Stocks\\ADI     Count: 35     Total size: 2.6690216064453125 MB
# X:\Raw_1_sec_Bar_Data\US_Stocks\\ADSK     Count: 35     Total size: 2.667064666748047 MB
# X:\Raw_1_sec_Bar_Data\US_Stocks\\AEO     Count: 35     Total size: 2.675004005432129 MB
# X:\Raw_1_sec_Bar_Data\US_Stocks\\AEP     Count: 35     Total size: 2.527080535888672 MB
# ...
