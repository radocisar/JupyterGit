# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Classification Exercise

# %% [markdown]
# For this exercise, we'll use water pump data from DrivenData.org
#
# Your goal is to predict the operating condition of a waterpoint for each record in the dataset.
#
# It is a multiclass classification problem with `status_group` as the target class.
#
# Take some time to read the data dictionary here: [https://www.drivendata.org/competitions/7/pump-it-up-data-mining-the-water-table/page/25](https://www.drivendata.org/competitions/7/pump-it-up-data-mining-the-water-table/page/25)

# %%
import pandas as pd

df = pd.read_csv("../assets/data/water_pumps.csv.gz")
df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private       ...        \
# 0  34.938093  -9.856322                  none            0       ...
# 1  34.698766  -2.147466              Zahanati            0       ...
# 2  37.460664  -3.821329           Kwa Mahundi            0       ...
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0       ...
# 4  31.130847  -1.825359               Shuleni            0       ...
#
#   water_quality quality_group      quantity  quantity_group  \
# ...

# %% [markdown]
# #### 1: There are a lot of columns, so instead of performing the usual EDA (Exploratory Data Analysis) on *all* columns, choose 3-4 columns to focus on and explore the data checking for (among other things):
#
# - missing values
# - strange values
# - distributions and relationships in your data

# %%
df['amount_tsh'].isna().sum()
df['gps_height'].isna().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 41 columns):
# id                       59400 non-null int64
# amount_tsh               59400 non-null float64
# date_recorded            59400 non-null object
# funder                   55765 non-null object
# gps_height               59400 non-null int64
# installer                55745 non-null object
# longitude                59400 non-null float64
# latitude                 59400 non-null float64
# wpt_name                 59400 non-null object
# num_private              59400 non-null int64
# basin                    59400 non-null object
# subvillage               59029 non-null object
# region                   59400 non-null object
# region_code              59400 non-null int64
# district_code            59400 non-null int64
# lga                      59400 non-null object
# ward                     59400 non-null object
# population               59400 non-null int64
# ...

# %%
df2.head(4)
# Out:
#                waterpoint_type     installer           source_type  \
# 0           communal standpipe         Roman                spring
# 1           communal standpipe       GRUMETI  rainwater harvesting
# 2  communal standpipe multiple  World vision                   dam
# 3  communal standpipe multiple        UNICEF              borehole
#
#   water_quality    status_group
# 0          soft      functional
# 1          soft      functional
# 2          soft      functional
# 3          soft  non functional

# %%
df.select_dtypes(exclude=object)
numerical_df=df[['amount_tsh','gps_height','population','construction_year','status_group']]
numerical_df.info()
#df2[df2['installer'].isna()]
#df2['installer'].isna().sum()
#df2['installer'].value_counts(dropna=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 5 columns):
# amount_tsh           59400 non-null float64
# gps_height           59400 non-null int64
# population           59400 non-null int64
# construction_year    59400 non-null int64
# status_group         59400 non-null object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.3+ MB

# %%
numerical_df.columns

for x in ['amount_tsh', 'gps_height', 'population', 'construction_year']:
    numerical_df = numerical_df[numerical_df[x] != 0]

# %%
numerical_df.reset_index(drop=True,inplace=True)
numerical_df
# Out:
#        amount_tsh  gps_height  population  construction_year  \
# 0          6000.0        1390         109               1999
# 1            25.0         686         250               2009
# 2           200.0        1062         250               1987
# 3           500.0        1703          35               1978
# 4           500.0        1763           1               1992
# 5           200.0        2216           4               2008
# 6           500.0         672         210               2011
# 7           500.0         200         260               2011
# 8            50.0         180         150               2004
# 9          4000.0        1955         100               2003
# 10           25.0         710          50               2008
# 11          500.0        1803         250               2011
# 12           20.0        1007         100               2000
# 13           20.0         240          30               2004
# ...

# %%
#df3=df2[df2.installer!="NaN"]
df3=df2.dropna(subset=['installer']) 
df3['installer'].value_counts(dropna=False)
# Out:
# DWE                      17402
# Government                1825
# RWE                       1206
# Commu                     1060
# DANIDA                    1050
# KKKT                       898
# Hesawa                     840
# 0                          777
# TCRS                       707
# Central government         622
# CES                        610
# Community                  553
# DANID                      552
# District Council           551
# HESAWA                     539
# World vision               408
# LGA                        408
# WEDECO                     397
# TASAF                      396
# District council           392
# Gover                      383
# AMREF                      329
# TWESA                      316
# WU                         301
# Dmdd                       287
# ACRA                       278
# World Vision               270
# SEMA                       249
# DW                         246
# OXFAM                      234
# ...

# %% [markdown]
# #### 2: how many rows are there in each class/label?

# %% [markdown]
# #### 3: Do a train-test split. What is the make-up of the labels in your train and test sets?

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(numerical_df.drop("status_group", axis=1),
                                                    numerical_df["status_group"],
                                                    test_size=0.3,
                                                    random_state=1)
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
accuracy_score(y_test, y_pred)

# %% [markdown]
# #### 4: Using your training set, obtain a basic KNN model's precision and efficiency

# %% [markdown]
# #### 5: BONUS - obtain a better value for k using cross validation score
#
# Hint: check this link for help
#
# https://www.ritchieng.com/machine-learning-efficiently-search-tuning-param/

# %% [markdown]
# #### 6: BONUS - obtain a better value for k using grid search - how much can you improve your score?
