# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Lab: Cleaning Rock Song Data
#
# ---

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Load `rock.csv` and do an initial examination of its data columns.

# %%
rockfile = "../data/rock.csv"

# %%
# Load the data
rock_songs=pd.read_csv(rockfile)
rock_songs
# Out:
#                                        Song Clean   ARTIST CLEAN Release Year  \
# 0                                Caught Up in You    .38 Special         1982
# 1                                    Fantasy Girl    .38 Special          NaN
# 2                                 Hold On Loosely    .38 Special         1981
# 3                          Rockin' Into the Night    .38 Special         1980
# 4                               Art For Arts Sake           10cc         1975
# 5                                      Kryptonite   3 Doors Down         2000
# 6                                           Loser   3 Doors Down         2000
# 7                                   When I'm Gone   3 Doors Down         2002
# 8                                      What's Up?  4 Non Blondes         1992
# 9                                      Take On Me           a-ha         1985
# 10                          Baby, Please Don't Go          AC/DC          NaN
# 11                                  Back In Black          AC/DC         1980
# 12                                        Big Gun          AC/DC         1993
# 13                         CAN'T STOP ROCK'N'ROLL          AC/DC          NaN
# 14                    Dirty Deeds Done Dirt Cheap          AC/DC         1976
# 15                        For Those About To Rock          AC/DC         1981
# 16                               Girls Got Rhythm          AC/DC          NaN
# 17                                 Hard As A Rock          AC/DC         1995
# 18                             Have a Drink On Me          AC/DC         1980
# 19                                    Hells Bells          AC/DC         1980
# 20                                Highway To Hell          AC/DC         1979
# 21                     It's A Long Way To The Top          AC/DC         1975
# 22                                      Jailbreak          AC/DC         1984
# 23                              Let There Be Rock          AC/DC         1977
# 24                                Let's Get It Up          AC/DC          NaN
# 25                                      Live Wire          AC/DC          NaN
# 26                                     Moneytalks          AC/DC          NaN
# 27                                  Night Prowler          AC/DC         1979
# 28            Rock and Roll Ain't Noise Pollution          AC/DC         1980
# 29                                Shoot To Thrill          AC/DC          NaN
# ...                                           ...            ...          ...
# 2200                      Owner of a Lonely Heart            Yes         1983
# 2201                                   Roundabout            Yes         1971
# 2202                             Starship Trooper            Yes         1971
# 2203                            Wonderous Stories            Yes          NaN
# 2204                         Yours Is No Disgrace            Yes         1971
# 2205                        Tell Me What You Want          Zebra          NaN
# 2206                        Who's Behind The Door          Zebra          NaN
# 2207                           Time of the Season        Zombies         1968
# 2208                    A Fool for Your Stockings         ZZ Top          NaN
# 2209             Arrested For Driving While Blind         ZZ Top         1976
# 2210                 Beer Drinkers & Hell Raisers         ZZ Top         1973
# 2211                             Cheap Sunglasses         ZZ Top         1980
# 2212                         Gimme All Your Lovin         ZZ Top         1983
# 2213                        Got Me Under Pressure         ZZ Top         1983
# 2214                            Heard It On the X         ZZ Top         1975
# 2215                                  I Thank You         ZZ Top          NaN
# 2216                      I'm Bad, I'm Nationwide         ZZ Top          NaN
# 2217                      Jesus Just Left Chicago         ZZ Top         1973
# 2218                                Just Got Paid         ZZ Top          NaN
# 2219                                    La Grange         ZZ Top         1973
# 2220                                         Legs         ZZ Top         1983
# 2221                     My Head's In Mississippi         ZZ Top          NaN
# 2222                           Party On The Patio         ZZ Top          NaN
# 2219                                La Grange by ZZ Top       1      1
# 2220                                     Legs by ZZ Top       1      1
# 2221                 My Head's In Mississippi by ZZ Top       1      0
# 2222                       Party On The Patio by ZZ Top       1      0
# 2223                           Pearl Necklace by ZZ Top       1      1
# 2224                        Sharp Dressed Man by ZZ Top       1      1
# 2225                  She Loves My Automobile by ZZ Top       1      0
# 2226                        Tube Snake Boogie by ZZ Top       1      1
# 2227                                     Tush by ZZ Top       1      1
# 2228                               TV Dinners by ZZ Top       1      1
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO by...       1      1
#
#       PlayCount  F*G
# 0            82   82
# 1             3    0
# 2            85   85
# 3            18   18
# 4             1    1
# 5            13   13
# 6             1    1
# 7             6    6
# 8             3    3
# 9             1    1
# 10            1    0
# 11           97   97
# 12            6    6
# 13            5    0
# 14           85   85
# 15           46   46
# 16           24    0
# 17            1    1
# 18           39   39
# 19           74   74
# 20           92   92
# 21           39   39
# 22            1    1
# 23            3    3
# 24            4    0
# 25            2    0
# 26           20    0
# 27            1    1
# 28           21   21
# 29           45    0
# ...         ...  ...
# 2200         81   81
# 2201         44   44
# 2202          1    1
# 2203          5    0
# 2204          1    1
# 2205          2    0
# 2206          1    0
# 2207         14   14
# 2208          1    0
# 2209          1    1
# 2210          8    8
# 2211         34   34
# 2212         86   86
# 2213         29   29
# 2214          2    2
# 2215         16    0
# 2216         10    0
# 2217          6    6
# 2218          2    0
# 2219        111  111
# 2220        121  121
# 2221          1    0
# 2222         14    0
# 2223          5    5
# 2224        120  120
# 2225          1    0
# 2226         32   32
# 2227        109  109
# 2228          1    1
# 2229          2    2
#
# [2230 rows x 8 columns]

# %%
# Look at the information regarding its columns.
rock_songs.columns
rock_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# Song Clean      2230 non-null object
# ARTIST CLEAN    2230 non-null object
# Release Year    1653 non-null object
# COMBINED        2230 non-null object
# First?          2230 non-null int64
# Year?           2230 non-null int64
# PlayCount       2230 non-null int64
# F*G             2230 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.5+ KB

# %% [markdown]
# ### 2.  Clean up the column names.
#
# Let's clean up the column names. There are two ways we can accomplish this:
#
# #### 2.A Change the column names when you import the data using `pd.read_csv()`.
#
# Notice that, when passing `names=[..A LIST OF STRING..]` with a number of columns that matches the number of strings in the passed list, you replace the column names.
#
# NOTE: When you create custom column names, the first row of the `.csv` already represents a header. It is important to tell `pandas` to skip that row. The `skiprows=1` keyword argument to `read_csv()` will tell `pandas` to skip the first row.

# %%
# Change the column names when loading the '.csv':
rock_songs=pd.read_csv(rockfile,skiprows=1,names=['song_name','artist_name','release_year','combined','first_?','year_?','play_count','f*g'])
rock_songs
# Out:
#                                         song_name    artist_name release_year  \
# 0                                Caught Up in You    .38 Special         1982
# 1                                    Fantasy Girl    .38 Special          NaN
# 2                                 Hold On Loosely    .38 Special         1981
# 3                          Rockin' Into the Night    .38 Special         1980
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO by...        1       1
#
#       play_count  f*g
# 0             82   82
# 1              3    0
# 2             85   85
# 3             18   18
# 4              1    1
# 5             13   13
# 6              1    1
# 7              6    6
# 8              3    3
# 9              1    1
# 10             1    0
# 11            97   97
# 12             6    6
# 13             5    0
# 14            85   85
# 15            46   46
# 16            24    0
# 17             1    1
# 18            39   39
# 19            74   74
# 20            92   92
# 21            39   39
# 22             1    1
# 23             3    3
# 24             4    0
# 25             2    0
# 26            20    0
# 27             1    1
# 28            21   21
# 29            45    0
# ...          ...  ...
# 2200          81   81
# 2201          44   44
# 2202           1    1
# 2203           5    0
# 2204           1    1
# 2205           2    0
# 2206           1    0
# 2207          14   14
# 2208           1    0
# 2209           1    1
# 2210           8    8
# 2211          34   34
# 2212          86   86
# 2213          29   29
# 2214           2    2
# 2215          16    0
# 2216          10    0
# 2217           6    6
# 2218           2    0
# 2219         111  111
# 2220         121  121
# 2221           1    0
# 2222          14    0
# 2223           5    5
# 2224         120  120
# 2225           1    0
# 2226          32   32
# 2227         109  109
# 2228           1    1
# 2229           2    2
#
# [2230 rows x 8 columns]

# %% [markdown]
# #### 2.B Change column names using the `.rename()` function.
#
# The `.rename()` function takes an argument, `columns=name_dict`, in which `name_dict` is a dictionary containing the original column names as keys and the new column names as values.

# %%
# Change the column names using the `.rename()` function.
rock_songs.rename(columns={'Song Clean':'song_name', 'ARTIST CLEAN':'artist_name', 'Release Year':'release_year', 'COMBINED':'combined', 'First?':'first_?',
       'Year?':'year_?', 'PlayCount':'play_count', 'F*G':'f*g'})
# Out:
#                                         song_name    artist_name  \
# 0                                      Song Clean   ARTIST CLEAN
# 1                                Caught Up in You    .38 Special
# 2                                    Fantasy Girl    .38 Special
# 3                                 Hold On Loosely    .38 Special
# 4                          Rockin' Into the Night    .38 Special
# 5                               Art For Arts Sake           10cc
# 6                                      Kryptonite   3 Doors Down
# 7                                           Loser   3 Doors Down
# 8                                   When I'm Gone   3 Doors Down
# 9                                      What's Up?  4 Non Blondes
# 10                                     Take On Me           a-ha
# 11                          Baby, Please Don't Go          AC/DC
# 12                                  Back In Black          AC/DC
# 13                                        Big Gun          AC/DC
# 14                         CAN'T STOP ROCK'N'ROLL          AC/DC
# 15                    Dirty Deeds Done Dirt Cheap          AC/DC
# 16                        For Those About To Rock          AC/DC
# 17                               Girls Got Rhythm          AC/DC
# 18                                 Hard As A Rock          AC/DC
# 19                             Have a Drink On Me          AC/DC
# 20                                    Hells Bells          AC/DC
# 21                                Highway To Hell          AC/DC
# 22                     It's A Long Way To The Top          AC/DC
# 23                                      Jailbreak          AC/DC
# 24                              Let There Be Rock          AC/DC
# 25                                Let's Get It Up          AC/DC
# 26                                      Live Wire          AC/DC
# 27                                     Moneytalks          AC/DC
# 28                                  Night Prowler          AC/DC
# 29            Rock and Roll Ain't Noise Pollution          AC/DC
# ...                                           ...            ...
# 2229      1          1    1
# 2230      1          2    2
#
# [2231 rows x 8 columns]

# %% [markdown]
# #### 2.C Reassigning the `.columns` attribute of a DataFrame.
#
# You can also just reassign the `.columns` attribute to a list of strings containing the new column names.
#
# The only caveat with reassigning `.columns` is that you have to reassign all of the column names at once. You can't partially replace a value by working on `.columns` directly. You have to reassign `.columns` with a list of equal length.

# %%
# Replace the column names by reassigning the `.columns` attribute.
rock_songs.columns=['song_name','artist_name','release_year','combined','first_?','year_?','play_count','f*g']
rock_songs
# Out:
#                                         song_name    artist_name release_year  \
# 0                                Caught Up in You    .38 Special         1982
# 1                                    Fantasy Girl    .38 Special          NaN
# 2                                 Hold On Loosely    .38 Special         1981
# 3                          Rockin' Into the Night    .38 Special         1980
# 4                               Art For Arts Sake           10cc         1975
# 5                                      Kryptonite   3 Doors Down         2000
# 6                                           Loser   3 Doors Down         2000
# 7                                   When I'm Gone   3 Doors Down         2002
# 8                                      What's Up?  4 Non Blondes         1992
# 9                                      Take On Me           a-ha         1985
# 10                          Baby, Please Don't Go          AC/DC          NaN
# 11                                  Back In Black          AC/DC         1980
# 12                                        Big Gun          AC/DC         1993
# 13                         CAN'T STOP ROCK'N'ROLL          AC/DC          NaN
# 14                    Dirty Deeds Done Dirt Cheap          AC/DC         1976
# 15                        For Those About To Rock          AC/DC         1981
# 16                               Girls Got Rhythm          AC/DC          NaN
# 17                                 Hard As A Rock          AC/DC         1995
# 18                             Have a Drink On Me          AC/DC         1980
# 19                                    Hells Bells          AC/DC         1980
# 20                                Highway To Hell          AC/DC         1979
# 21                     It's A Long Way To The Top          AC/DC         1975
# 22                                      Jailbreak          AC/DC         1984
# 23                              Let There Be Rock          AC/DC         1977
# 24                                Let's Get It Up          AC/DC          NaN
# 25                                      Live Wire          AC/DC          NaN
# 26                                     Moneytalks          AC/DC          NaN
# 27                                  Night Prowler          AC/DC         1979
# 28            Rock and Roll Ain't Noise Pollution          AC/DC         1980
# 29                                Shoot To Thrill          AC/DC          NaN
# ...                                           ...            ...          ...
# 2200                      Owner of a Lonely Heart            Yes         1983
# 2201                                   Roundabout            Yes         1971
# 2202                             Starship Trooper            Yes         1971
# 2203                            Wonderous Stories            Yes          NaN
# 2204                         Yours Is No Disgrace            Yes         1971
# 2205                        Tell Me What You Want          Zebra          NaN
# 2206                        Who's Behind The Door          Zebra          NaN
# 2207                           Time of the Season        Zombies         1968
# 2208                    A Fool for Your Stockings         ZZ Top          NaN
# 2209             Arrested For Driving While Blind         ZZ Top         1976
# 2210                 Beer Drinkers & Hell Raisers         ZZ Top         1973
# 2211                             Cheap Sunglasses         ZZ Top         1980
# 2212                         Gimme All Your Lovin         ZZ Top         1983
# 2213                        Got Me Under Pressure         ZZ Top         1983
# 2214                            Heard It On the X         ZZ Top         1975
# 2215                                  I Thank You         ZZ Top          NaN
# 2216                      I'm Bad, I'm Nationwide         ZZ Top          NaN
# 2217                      Jesus Just Left Chicago         ZZ Top         1973
# 2214                        Heard It On the X by ZZ Top        1       1
# 2215                              I Thank You by ZZ Top        1       0
# 2216                  I'm Bad, I'm Nationwide by ZZ Top        1       0
# 2217                  Jesus Just Left Chicago by ZZ Top        1       1
# 2218                            Just Got Paid by ZZ Top        1       0
# 2219                                La Grange by ZZ Top        1       1
# 2220                                     Legs by ZZ Top        1       1
# 2221                 My Head's In Mississippi by ZZ Top        1       0
# 2222                       Party On The Patio by ZZ Top        1       0
# 2223                           Pearl Necklace by ZZ Top        1       1
# 2224                        Sharp Dressed Man by ZZ Top        1       1
# 2225                  She Loves My Automobile by ZZ Top        1       0
# 2226                        Tube Snake Boogie by ZZ Top        1       1
# 2227                                     Tush by ZZ Top        1       1
# 2228                               TV Dinners by ZZ Top        1       1
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO by...        1       1
#
#       play_count  f*g
# 0             82   82
# 1              3    0
# 2             85   85
# 3             18   18
# 4              1    1
# 5             13   13
# 6              1    1
# 7              6    6
# 8              3    3
# 9              1    1
# 10             1    0
# 11            97   97
# 12             6    6
# 13             5    0
# 14            85   85
# 15            46   46
# 16            24    0
# 17             1    1
# 18            39   39
# 19            74   74
# 20            92   92
# 21            39   39
# 22             1    1
# 23             3    3
# 24             4    0
# 25             2    0
# 26            20    0
# 27             1    1
# 28            21   21
# 29            45    0
# ...          ...  ...
# 2200          81   81
# 2201          44   44
# 2202           1    1
# 2203           5    0
# 2204           1    1
# 2205           2    0
# 2206           1    0
# 2207          14   14
# 2208           1    0
# 2209           1    1
# 2210           8    8
# 2211          34   34
# 2212          86   86
# 2213          29   29
# 2214           2    2
# 2215          16    0
# 2216          10    0
# 2217           6    6
# 2218           2    0
# 2219         111  111
# 2220         121  121
# 2221           1    0
# 2222          14    0
# 2223           5    5
# 2224         120  120
# 2225           1    0
# 2226          32   32
# 2227         109  109
# 2228           1    1
# 2229           2    2
#
# [2230 rows x 8 columns]

# %% [markdown]
# ### 3. Subsetting data where null values exist.
#
# We have mixed `str` and `NaN` values in the `release` column. `NaN` stands for "not a number" and is the way `pandas` handles "nulls" or nonexistent data. We can use the `.isnull()` method of a Series to find null values.
#
# Print the header of the data subset to where the `release` column is null values.

# %%
# Show records where df['release'] is null
rock_songs[rock_songs['release_year'].isnull()].head(5)
# Out:
#                  song_name  artist_name release_year  \
# 1             Fantasy Girl  .38 Special          NaN
# 10   Baby, Please Don't Go        AC/DC          NaN
# 13  CAN'T STOP ROCK'N'ROLL        AC/DC          NaN
# 16        Girls Got Rhythm        AC/DC          NaN
# 24         Let's Get It Up        AC/DC          NaN
#
#                            combined  first_?  year_?  play_count  f*g
# 1       Fantasy Girl by .38 Special        1       0           3    0
# 10   Baby, Please Don't Go by AC/DC        1       0           1    0
# 13  CAN'T STOP ROCK'N'ROLL by AC/DC        1       0           5    0
# 16        Girls Got Rhythm by AC/DC        1       0          24    0
# 24         Let's Get It Up by AC/DC        1       0           4    0

# %% [markdown]
# ### 4. Update slices of your DataFrame based on mask selection/slices.
#
# In many scenarios, we want to upate values in our DataFrame according to criteria. Let's say we wanted to set all of the null values in `release` to 0.
#
# With newer versions of `pandas`, in order to manipulate data in the original DataFrame, we have to use `.loc` while performing reassignment using a mask and an index.
#
# For example, the following won't always work:
# ```python
# df[row_mask]['column_name'] = new_value
# ```
#
# The best way to accomplish the same task is:
# ```python
# df.loc[row_mask, 'column_name'] = new_value
# ```
#
# For multiple column assignment, you would use:
# ```python
# df.loc[row_mask, ['col_1', 'col_2', 'col_3']] = new_value
# ```
#
# #### 4.A Let's try it out. Make all of the null values in `release` 0.

# %%
# Replace release nulls with 0
'''I am not sure it is correct because I work with a subset
and not with an original dataframe'''
rock_songs['release_year'].fillna(value=0,inplace=True)
rock_songs.head(5)
#tried this but this does not work
#rock_songs[rock_songs['release_year'].isnull()].loc[:,'release_year']=0
# Out:
#                 song_name  artist_name release_year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special            0
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 combined  first_?  year_?  play_count  f*g
# 0        Caught Up in You by .38 Special        1       1          82   82
# 1            Fantasy Girl by .38 Special        1       0           3    0
# 2         Hold On Loosely by .38 Special        1       1          85   85
# 3  Rockin' Into the Night by .38 Special        1       1          18   18
# 4              Art For Arts Sake by 10cc        1       1           1    1

# %% [markdown]
# #### 4.B Verify that `release` contains no null values.

# %%
# A: 
print(rock_songs['release_year'].isnull().sum())
# Out:
# 0

# %% [markdown]
# ### 5. Ensure that the data types of the columns make sense.
#
# Verifying column data types is a critical part of data munging. If columns have the wrong data type, then there is usually corrupted or incorrect data in some of the observations.
#
# #### 5.A Look at the data types for the columns. Are any incorrect given what the data represents?

# %%
# A:
rock_songs.dtypes
# Out:
# song_name       object
# artist_name     object
# release_year    object
# combined        object
# first_?          int64
# year_?           int64
# play_count       int64
# f*g              int64
# dtype: object

# %% [markdown]
# ### 6. Investigate and clean up the `release` column.
#
# The `release` column is a string data type when it should be an integer.
#
# #### 6.A Figure out what value(s) are causing the `release` column to be encoded as a string instead of an integer.

# %%
# A:not sure it 
rock_songs['release_year'].value_counts()
# Out:
# 0                577
# 1973             104
# 1975              83
# 1977              83
# 1970              81
# 1971              75
# 1969              72
# 1980              70
# 1978              64
# 1979              63
# 1967              61
# 1981              61
# 1983              60
# 1976              56
# 1982              54
# 1984              51
# 1972              50
# 1974              48
# 1968              46
# 1987              39
# 1985              39
# 1986              37
# 1991              34
# 1989              32
# 1966              30
# 1988              29
# 1965              28
# 1994              25
# 1990              22
# 1993              19
# 1992              14
# 1964              14
# 1999              13
# 1995              10
# 1963               9
# 1997               9
# 1996               9
# 2002               6
# 1998               6
# 2005               5
# 2004               5
# 2012               5
# 2001               4
# 2003               3
# 1962               3
# 2000               3
# 2008               3
# 2007               3
# 2011               3
# 2014               2
# 2013               2
# 1958               1
# 2006               1
# SONGFACTS.COM      1
# 1955               1
# 1071               1
# 1961               1
# Name: release_year, dtype: int64

# %% [markdown]
# #### 6.B Look at the rows in which there is incorrect data in the `release` column.

# %%
# A:
rock_songs[rock_songs.release_year=='SONGFACTS.COM']
# Out:
#            song_name     artist_name   release_year  \
# 1504  Bullfrog Blues  Rory Gallagher  SONGFACTS.COM
#
#                               combined  first_?  year_?  play_count  f*g
# 1504  Bullfrog Blues by Rory Gallagher        1       1           1    1

# %% [markdown]
# #### 6.C. Clean up the data by making it numeric.
#
# Normally we may replace the offending data with null `np.nan` values, however we previously converted all of the nan values in the release column to zeros so we might as well continue with the same practice. Replacing with 0 (or nan) will allow us to convert the column to numeric.

# %%
# A:
rock_songs.release_year.replace('SONGFACTS.COM',0,inplace=True)

# %% [markdown]
# ### 7. Get summary statistics for the `release` column using the `.describe()` function.
#
# Now that the `release` column is finally a numeric data type, we can apply the `.describe()` function.
#
# #### 7.A Print out the summary stats for the `release` column. What is the earliest and latest release date?

# %%
# A. I cannot override the values inside of original frame!
rock_songs['release_year']=rock_songs['release_year'].astype(int)
#rock_songs = pd.to_numeric(rock_songs['release_year'], downcast='integer')
rock_songs
rock_songs.describe()
# Out:
#        release_year  first_?       year_?   play_count          f*g
# count   2230.000000   2230.0  2230.000000  2230.000000  2230.000000
# mean    1465.331390      1.0     0.741256    16.872646    15.048430
# std      867.196161      0.0     0.438043    25.302972    25.288366
# min        0.000000      1.0     0.000000     0.000000     0.000000
# 25%        0.000000      1.0     0.000000     1.000000     0.000000
# 50%     1973.000000      1.0     1.000000     4.000000     3.000000
# 75%     1981.000000      1.0     1.000000    21.000000    18.000000
# max     2014.000000      1.0     1.000000   142.000000   142.000000

# %% [markdown]
# #### 7.B Based on the summary statistics, is there anything else wrong with the `release` column?

# %%
# A: not sure! may be the min is 0 which is actually not true?

# %% [markdown]
# ### 8. Make changes and investigate using custom functions with `.apply()`.
#
# Let's say we want to traverse every single row in our data set and apply a function to that row.
#
# #### 8.A Write a function that will take a row of a DataFrame and print out the song, artist, and whether or not the release date is < 1970.

# %%
# A: for some reason does not populate song name?
#it only works with axis=1...otherwise get an error
rock_songs['song_artist_1970']=rock_songs.apply(lambda row: row["release_year"]<1970 and row['song_name'] and row['artist_name'],axis=1)
#rock_songs

# %% [markdown]
# #### 8.B Using the `.apply()` function, apply the function you wrote to the first four rows of the DataFrame.
#
# You will need to tell the `apply` function to operate row by row. Setting the keyword argument as `axis=1` indicates that the function should be applied to each row individually.

# %%
# A:see above?

# %% [markdown]
# You'll notice that there will be a final output Series of `None` values. The `.apply()` function, if a return value is not specified, will return a Series of `None` values (similar to how the default return for Python functions is `None` when a return statement is not specified).

# %% [markdown]
# ### 9. Write a function that converts cells in a DataFrame to float and otherwise replaces them with `np.nan`.
#
# If applied to our data, it would keep only the numeric information and otherwise input null values.
#
# You can use this try-except syntax in Python as a great way to try something and take another action if the initial step fails:
#
# ```python
# try:
#     Perform some action.
# except:
#     Perform some other action if the first failed with an error.
# ```
#
# #### 9.A Write the function that takes a column and converts all of its values to float if possible and `np.nan` otherwise. The return value should be the converted Series.

# %%
# loading a data frame again to test on release_year
rock_songs=pd.read_csv(rockfile,skiprows=1,names=['song_name','artist_name','release_year','combined','first_?','year_?','play_count','f*g'])
rock_songs.head(5)
# Out:
#                 song_name  artist_name release_year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special          NaN
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 combined  first_?  year_?  play_count  f*g
# 0        Caught Up in You by .38 Special        1       1          82   82
# 1            Fantasy Girl by .38 Special        1       0           3    0
# 2         Hold On Loosely by .38 Special        1       1          85   85
# 3  Rockin' Into the Night by .38 Special        1       1          18   18
# 4              Art For Arts Sake by 10cc        1       1           1    1

# %%
def convert_to_float(col):
    col_name=col.name
    col_data=[]
    for entry in col:
        try:
                 col_data.append(float(entry))
        except:
                 col_data.append(np.nan)
    new_col=pd.Series(data=col_data,name=col_name)
    
    return new_col.head(5)

convert_to_float(rock_songs["release_year"])
# Out:
# 0    1982.0
# 1       NaN
# 2    1981.0
# 3    1980.0
# 4    1975.0
# Name: release_year, dtype: float64

# %% [markdown]
# #### 9.B Try your function out on the rock song data and ensure the output is what you expected.

# %%
# A:
rock_songs.apply(convert_to_float).head()
# Out:
#    song_name  artist_name  release_year  combined  first_?  year_?  \
# 0        NaN          NaN        1982.0       NaN      1.0     1.0
# 1        NaN          NaN           NaN       NaN      1.0     0.0
# 2        NaN          NaN        1981.0       NaN      1.0     1.0
# 3        NaN          NaN        1980.0       NaN      1.0     1.0
# 4        NaN          NaN        1975.0       NaN      1.0     1.0
#
#    play_count   f*g
# 0        82.0  82.0
# 1         3.0   0.0
# 2        85.0  85.0
# 3        18.0  18.0
# 4         1.0   1.0

# %% [markdown]
# #### 9.C Describe the new float-only DataFrame.

# %%
# A:
rock_songs.apply(convert_to_float).describe()
# Out:
#        song_name  artist_name  release_year  combined  first_?    year_?  \
# count        0.0          0.0      4.000000       0.0      5.0  5.000000
# mean         NaN          NaN   1979.500000       NaN      1.0  0.800000
# std          NaN          NaN      3.109126       NaN      0.0  0.447214
# min          NaN          NaN   1975.000000       NaN      1.0  0.000000
# 25%          NaN          NaN   1978.750000       NaN      1.0  1.000000
# 50%          NaN          NaN   1980.500000       NaN      1.0  1.000000
# 75%          NaN          NaN   1981.250000       NaN      1.0  1.000000
# max          NaN          NaN   1982.000000       NaN      1.0  1.000000
#
#        play_count        f*g
# count     5.00000   5.000000
# mean     37.80000  37.200000
# std      42.24571  42.880065
# min       1.00000   0.000000
# 25%       3.00000   1.000000
# 50%      18.00000  18.000000
# 75%      82.00000  82.000000
# max      85.00000  85.000000
