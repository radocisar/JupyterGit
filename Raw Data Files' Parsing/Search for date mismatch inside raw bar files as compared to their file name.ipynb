# %% [markdown]
# # New files from 09/20/2018 (inclusive)

# %%
import pandas as pd
import os
import patoolib
import datetime as dt
import pytz
import shutil
import pickle
import gzip
from tqdm import tqdm_notebook

# %% [markdown]
# ## To remove all *.txt files from C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks

# %%
Files_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks"

for folder in tqdm_notebook(os.listdir(Files_Folder)):
    #print(folder)
    Indv_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\" + folder
    #print(Indv_Folder)
    for file in os.listdir(Indv_Folder):
        if file.endswith(".txt"):
            os.remove(str(Indv_Folder+"\\"+file))

# %% [markdown]
# ## To convert all *.txt.gz files in C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks into *.txt files

# %% [markdown]
# ### For 1 security

# %%
Indv_Folder = r"K:\Raw_1_sec_Bar_Data\FX\EURGBP"
Ext_Folder = r"K:\Raw_1_sec_Bar_Data\FX\EURGBP\Extracted"
for file in tqdm_notebook(os.listdir(Indv_Folder)):
    patoolib.extract_archive(str(Indv_Folder+"\\"+file), outdir=Ext_Folder)
# Out:
# patool: Extracting K:\Raw_1_sec_Bar_Data\FX\EURGBP\EURGBP_Bars_20190909.txt.gz ...
# patool: running "C:\Program Files\7-Zip\7z.EXE" e -oK:\Raw_1_sec_Bar_Data\FX\EURGBP\Extracted -- K:\Raw_1_sec_Bar_Data\FX\EURGBP\EURGBP_Bars_20190909.txt.gz
# patool: ... K:\Raw_1_sec_Bar_Data\FX\EURGBP\EURGBP_Bars_20190909.txt.gz extracted to `K:\Raw_1_sec_Bar_Data\FX\EURGBP\Extracted'.
# patool: Extracting K:\Raw_1_sec_Bar_Data\FX\EURGBP\EURGBP_Bars_20190910.txt.gz ...
# patool: running "C:\Program Files\7-Zip\7z.EXE" e -oK:\Raw_1_sec_Bar_Data\FX\EURGBP\Extracted -- K:\Raw_1_sec_Bar_Data\FX\EURGBP\EURGBP_Bars_20190910.txt.gz
# patool: ... K:\Raw_1_sec_Bar_Data\FX\EURGBP\EURGBP_Bars_20190910.txt.gz extracted to `K:\Raw_1_sec_Bar_Data\FX\EURGBP\Extracted'.
# patool: Extracting K:\Raw_1_sec_Bar_Data\FX\EURGBP\EURGBP_Bars_20190911.txt.gz ...
# patool: running "C:\Program Files\7-Zip\7z.EXE" e -oK:\Raw_1_sec_Bar_Data\FX\EURGBP\Extracted -- K:\Raw_1_sec_Bar_Data\FX\EURGBP\EURGBP_Bars_20190911.txt.gz
# ...

# %% [markdown]
# ### For multiple securities

# %%
Files_Folder = r"K:\Raw_1_sec_Bar_Data\FX\EURUSD"

for folder in tqdm_notebook(os.listdir(Files_Folder)):
    print(folder)
    Indv_Folder = r"K:\Raw_1_sec_Bar_Data\FX\EURUSD\\" + folder
    print(Indv_Folder)
    for file in os.listdir(Indv_Folder):
        patoolib.extract_archive(str(Indv_Folder+"\\"+file),
                                  outdir=Indv_Folder)

# %% [markdown]
# ## To search for date mismatch inside the files

# %% [markdown]
# To find if the the date in the file name matches up with the date inside the file

# %% [markdown]
# ### For 1 security

# %%
Indv_Folder = r"K:\Raw_1_sec_Bar_Data\FX\EURGBP\Extracted"
    #print(Indv_Folder)
for file in tqdm_notebook(os.listdir(Indv_Folder)):
#         patoolib.extract_archive(str(Indv_Folder+"\\"+file),
#                                   outdir=Indv_Folder)
    if file.endswith(".txt"):
            #print(file)
        fd = file[len(file)-12:-4]
            #print(fd)
        df = pd.read_csv(Indv_Folder+"\\"+file,delimiter="|", header=0,index_col=0,parse_dates=True)
            #print(df.index.strftime("%Y%m%d"))
        df_index_list = df.index.strftime("%Y%m%d").values.tolist()
            #print(df_index_list[:10])
        for i in df_index_list:
            if i == fd:
                pass
            else:
                print("Date mismatch. File: {} | File date: {} whereas item date {}. Occured at line #: {}.".
                        format(file,fd,i,df_index_list.index(i)+2))
# Out:
# C:\Users\radoC\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %% [markdown]
# ### For multiple securities

# %%
Files_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks"

for folder in tqdm.notebook(os.listdir(Files_Folder)):
    print(folder)
    Indv_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks\\" + folder
    #print(Indv_Folder)
    for file in os.listdir(Indv_Folder):
#         patoolib.extract_archive(str(Indv_Folder+"\\"+file),
#                                   outdir=Indv_Folder)
        if file.endswith(".txt"):
            #print(file)
            fd = file[len(file)-12:-4]
            #print(fd)
            df = pd.read_csv(Indv_Folder+"\\"+file,delimiter="|",
                             header=0,index_col=0,parse_dates=True)
            #print(df.index.strftime("%Y%m%d"))
            df_index_list = df.index.strftime("%Y%m%d").values.tolist()
            #print(df_index_list[:10])
            for i in df_index_list:
                if i == fd:
                    pass
                else:
                    print("Date mismatch. File: {} | File date: {} whereas item date {}. Occured at line #: {}.".
                          format(file,fd,i,df_index_list.index(i)+2))
# Out:
# ADP
# ANET
# CENX
# ECR
# INTU
# OMC
# SEAS
# TSCO
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# Date mismatch. File: TSCO_Bars_20180806.txt | File date: 20180806 whereas item date 20180807. Occured at line #: 2.
# ...

# %% [markdown]
# ### Removing last two columns (VOLUME, COUNT) from raw FX files

# %% [markdown]
# ### For 1 security

# %%
Indv_Folder = r"K:\Raw_1_sec_Bar_Data\FX\EURGBP\Extracted"
    #print(Indv_Folder)
for file in tqdm_notebook(os.listdir(Indv_Folder)):
    if file.endswith(".txt"):
        df = pd.read_csv(Indv_Folder+"\\"+file,delimiter="|",
                             header=0,index_col=0,parse_dates=True)
        df.drop(["Volume", "Count", df.columns[-1]], axis=1, inplace=True)
        df.to_csv(Indv_Folder+"\\"+file, sep="|")
# Out:
# C:\Users\radoC\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %% [markdown]
# ### For multiple securities

# %%
Files_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks"

for folder in tqdm_notebook(os.listdir(Files_Folder)):
    print(folder)
    Indv_Folder = r"K:\Raw_1_sec_Bar_Data\FX\GBPUSD\Extracted\\" + folder
    #print(Indv_Folder)
        for file in os.listdir(Indv_Folder):
            if file.endswith(".txt"):
                df = pd.read_csv(Indv_Folder+"\\"+file,delimiter="|",
                                     header=0,index_col=0,parse_dates=True)
                df.drop(["Volume", "Count", df.columns[-1]], axis=1, inplace=True)
                df.to_csv(Indv_Folder+"\\"+file, sep="|")

# %% [markdown]
# ### Removing extra data after 22:00 (non-DST) 21:00 (DST) on Fridays and extra data between 21:59:59 (or 20:59:59) and 22:15:00 (or 21:15:00) on other days

# %% [markdown]
# ### For 1 security

# %%
# UK_dst_2018_start = dt.datetime(2018,3,25)
# UK_dst_2018_end = dt.datetime(2018,10,28)
# UK_dst_2019_start = dt.datetime(2019,3,31)
# UK_dst_2019_end = dt.datetime(2019,10,27)

Indv_Folder = r"K:\Raw_1_sec_Bar_Data\FX\EURGBP\Extracted"
    #print(Indv_Folder)
for file in tqdm_notebook(os.listdir(Indv_Folder)):
    fd = dt.datetime.strptime(file[len(file)-12:-4],"%Y%m%d")
    df = pd.read_csv(Indv_Folder+"\\"+file,delimiter="|",
                             header=0,index_col=0,parse_dates=True)
    # if Friday:
    if fd.weekday() == 4:
#         # if date of file falls within DST period:
#         if (UK_dst_2018_start < fd < UK_dst_2018_end) | \
#             (UK_dst_2019_start < fd < UK_dst_2019_end):
#             # return all rows until 20:59:59
#             correct_df = df.iloc[0:75600,:]
#         # if date of file does not fall within DST period:
#         else:
#             # return all rows until 21:59:59
#             correct_df = df.iloc[0:79200,:]
        correct_df = df[~df.index.duplicated()]
    # if other day:
    else:
        correct_df = df[~df.index.duplicated()]
    correct_df.to_csv(Indv_Folder+"\\"+file, sep="|")
# Out:
# C:\Users\radoC\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %% [markdown]
# ## Re-add missing times which will have blank data (15 minutes on weekdays ex Friday)

# %% [markdown]
# ### For 1 security

# %%
Indv_Folder = r"K:\Raw_1_sec_Bar_Data\FX\EURGBP\Extracted"
    #print(Indv_Folder)
for file in tqdm_notebook(os.listdir(Indv_Folder)):
#         patoolib.extract_archive(str(Indv_Folder+"\\"+file),
#                                   outdir=Indv_Folder)
    if file.endswith(".txt"):
        print(file)
        df = pd.read_csv(Indv_Folder+"\\"+file,delimiter="|", header=0,index_col=0,parse_dates=True)
        ndf = df.asfreq(freq="S")
        ndf.to_csv(Indv_Folder+"\\"+file, sep="|")
# Out:
# C:\Users\radoC\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...
# EURGBP_Bars_20190909.txt
# EURGBP_Bars_20190910.txt
# EURGBP_Bars_20190911.txt
# EURGBP_Bars_20190912.txt
# EURGBP_Bars_20190913.txt
# EURGBP_Bars_20190916.txt
# EURGBP_Bars_20190917.txt
# EURGBP_Bars_20190918.txt
# EURGBP_Bars_20190919.txt
# EURGBP_Bars_20190920.txt
# EURGBP_Bars_20190923.txt
# EURGBP_Bars_20190924.txt
# EURGBP_Bars_20190925.txt
# EURGBP_Bars_20190926.txt
# EURGBP_Bars_20190927.txt
# EURGBP_Bars_20190930.txt
# EURGBP_Bars_20191001.txt
# EURGBP_Bars_20191002.txt
# EURGBP_Bars_20191003.txt
# EURGBP_Bars_20191004.txt
# EURGBP_Bars_20191007.txt
# EURGBP_Bars_20191008.txt
# EURGBP_Bars_20191009.txt
# EURGBP_Bars_20191010.txt
# EURGBP_Bars_20191011.txt
# ...

# %% [markdown]
# ### For multiple securities

# %%
Files_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks"

for folder in tqdm_notebook(os.listdir(Files_Folder)):
    print(folder)
    Indv_Folder = r"K:\Raw_1_sec_Bar_Data\FX\GBPUSD\Extracted\\" + folder
    #print(Indv_Folder)
        for file in os.listdir(Indv_Folder):
#         patoolib.extract_archive(str(Indv_Folder+"\\"+file),
#                                   outdir=Indv_Folder)
            if file.endswith(".txt"):
                    #print(file)
                df = pd.read_csv(Indv_Folder+"\\"+file,delimiter="|", header=0,index_col=0,parse_dates=True)
                ndf = df.asfreq(freq="S")
                ndf.to_csv(Indv_Folder+"\\"+file, sep="|")

# %% [markdown]
# ## Copy downloaded files from download folder to storage folder

# %% [markdown]
# ### For 1 security

# %%
### For Extracted files:
File_In_Folder = r"K:\Raw_1_sec_Bar_Data\FX\EURGBP\Extracted"
File_Out_Folder = r"L:\Raw_1_sec_Bar_Data\FX\EURGBP\Extracted"
    #print(Indv_Folder)
for file in tqdm_notebook(os.listdir(File_In_Folder),"Copying and Removing Extracted Files"):
    file_in = File_In_Folder+"\\"+file
    file_out = File_Out_Folder+"\\"+file
    shutil.copyfile(file_in,file_out)
    os.remove(File_In_Folder+"\\"+file)
### For .gz files:
File_In_Folder = r"K:\Raw_1_sec_Bar_Data\FX\EURGBP"
File_Out_Folder = r"L:\Raw_1_sec_Bar_Data\FX\EURGBP"
    #print(Indv_Folder)
for file in tqdm_notebook(os.listdir(File_In_Folder),"Copying and Removing Compressed Files"):
    file_in = File_In_Folder+"\\"+file
    file_out = File_Out_Folder+"\\"+file
    if file != "Extracted":
        shutil.copyfile(file_in,file_out)
        os.remove(File_In_Folder+"\\"+file)
    else:
        os.remove(File_In_Folder+"\\"+file)
# Out:
# C:\Users\radoC\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# ...
# C:\Users\radoC\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-17-39fa68229da5> in <module>
#      19         os.remove(File_In_Folder+"\\"+file)
#      20     else:
# ---> 21         os.remove(File_In_Folder+"\\"+file)
#
# PermissionError: [WinError 5] Access is denied: 'K:\\Raw_1_sec_Bar_Data\\FX\\EURGBP\\Extracted'

# %% [markdown]
# ### For multiple securities

# %%
### For .gz files:
Files_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks"

for folder in tqdm_notebook(os.listdir(Files_Folder),"Copying and Removing Extracted Files"):
    
    File_In_Folder = r"K:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks" + folder
    File_Out_Folder = r"L:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks" + folder
    
    for file in os.listdir(File_In_Folder):
        file_in = File_In_Folder+"\\"+file
        file_out = File_Out_Folder+"\\"+file
        shutil.copyfileobj(file_in,file_out)
        os.remove(File_In_Folder+"\\"+file)
### For Extracted files:
Files_Folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks"

for folder in tqdm_notebook(os.listdir(Files_Folder),"Copying and Removing Compressed Files"):
    
    File_In_Folder = r"K:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks" + folder + "\\Extracted"
    File_Out_Folder = r"L:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks" + folder + "\\Extracted"
    
    for file in os.listdir(File_In_Folder):
        file_in = File_In_Folder+"\\"+file
        file_out = File_Out_Folder+"\\"+file
        shutil.copyfileobj(file_in,file_out)
        os.remove(File_In_Folder+"\\"+file)

# %% [markdown]
# ## Pickle .txt files and compress the pickle

# %% [markdown]
# ### For 1 security

# %%
Files_folder = r"L:\Raw_1_sec_Bar_Data\FX\EURGBP"
file_name = Files_folder.split("\\")[-1]

Indv_Folder = Files_folder+"\\"+"Extracted"
df_for_pickle = pd.DataFrame()
    #print(Indv_Folder)
for file in tqdm_notebook(os.listdir(Indv_Folder)):
    df = pd.read_csv(Indv_Folder+"\\"+file,delimiter="|", header=0,index_col=0,parse_dates=True)
    df_for_pickle = pd.concat([df_for_pickle, df])
pickle_file = open(Files_folder+"\\Pickle\\"+file_name+".pkl","wb")
pickle.dump(df_for_pickle, pickle_file)
pickle_file.close()
file_in = open(Files_folder+"\\Pickle\\"+file_name+".pkl","rb")
file_out = gzip.open(Files_folder+"\\Pickle\\"+file_name+".pkl.gz","wb")
shutil.copyfileobj(file_in,file_out)
file_in.close()
file_out.close()
os.remove(Files_folder+"\\Pickle\\"+file_name+".pkl")
# Out:
# C:\Users\radoC\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# ...

# %% [markdown]
# ### After above is run (for each security):
# * rename pre-existing *_all_files.pkl.gz to *_<date>.pkl.gz
# * rename newly created pkl file to *_all_files.pkl.gz

# %% [markdown]
# ### For multiple securities

# %%
Files_folder = r"C:\Raw_Data\Raw_1_sec_Bar_Data\US_Stocks"
file_name = Files_folder.split("\\")[-1]

for folder in tqdm_notebook(os.listdir(Files_Folder)):
    Indv_Folder = Files_folder+"\\"+folder+"\\"+"Extracted"
    df_for_pickle = pd.DataFrame()
        #print(Indv_Folder)
    for file in os.listdir(Indv_Folder):
        df = pd.read_csv(Indv_Folder+"\\"+file,delimiter="|", header=0,index_col=0,parse_dates=True)
        df_for_pickle = pd.concat([df_for_pickle, df])
    pickle_file = open(Files_folder+"\\"+folder+"\\Pickle\\"+file_name+".pkl","wb")
    pickle.dump(df_for_pickle, pickle_file)
    pickle_file.close()
    file_in = open(Files_folder+"\\Pickle\\"+file_name+".pkl","rb")
    file_out = gzip.open(Files_folder+"\\Pickle\\"+file_name+".pkl.gz","wb")
    shutil.copyfileobj(file_in,file_out)
    file_in.close()
    file_out.close()
    os.remove(Files_folder+"\\Pickle\\"+file_name+".pkl")

# %% [markdown]
# ### After above is run (for each security):
# * rename pre-existing *_all_files.pkl.gz to *_<date>.pkl.gz
# * rename newly created pkl file to *_all_files.pkl.gz
